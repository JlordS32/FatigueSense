# %%
import os, shutil, random

TRAIN_RATIO = 0.85
images_src = "dataset_1/images"
labels_src = "dataset_1/labels"

images = [f for f in os.listdir(images_src) if f.endswith(".png")]
random.seed(42)
random.shuffle(images)

for folder in ["data/images/train", "data/images/val", "data/labels/train", "data/labels/val"]:
    os.makedirs(folder, exist_ok=True)

for i, img in enumerate(images):
    label = img.replace(".png", ".txt")
    dest = "train" if i < int(len(images) * TRAIN_RATIO) else "val"

    shutil.copy(os.path.join(images_src, img), os.path.join("data/images", dest, img))
    label_path = os.path.join(labels_src, label)
    if os.path.exists(label_path):
        shutil.copy(label_path, os.path.join("data/labels", dest, label))

print(f"Done — train: {int(len(images) * TRAIN_RATIO)}, val: {len(images) - int(len(images) * TRAIN_RATIO)}")
# Out:
# Done — train: 363, val: 65

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.6.0+cu124
# True

# %%
from ultralytics import YOLO
from clearml import Task

task = Task.init(project_name="Main", task_name="YOLO Training")

model = YOLO("yolo11n.pt")
model.train(
    data="dataset_1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    project="runs",
    name="fatigue-v1",
    device=0
)

task.close()
# Out:
# ClearML Task: created new task id=85386273e84548cf9de6d93af821b8b5
# ClearML results page: https://app.clear.ml/projects/bab4f98ba6d147688fafe06e98131cbe/experiments/85386273e84548cf9de6d93af821b8b5/output/log
# Ultralytics 8.4.25  Python-3.13.3 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_1/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=fatigue-v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\jlord\OneDrive\Documents\Programming\FatigueSense\runs\detect\runs\fatigue-v1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 12.8MB/s 0.4s.4s<0.0s.8s
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 939.2327.9 MB/s, size: 1556.8 KB)
# train: Scanning C:\Users\jlord\OneDrive\Documents\Programming\FatigueSense\data\labels\train.cache... 363 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━
GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 4.2it/s 0.7s0.6s
#                    all         65        156      0.979      0.978      0.994      0.875
#                  Torso         65         65      0.996          1      0.995      0.979
#                   Eyes         20         26          1      0.912      0.993       0.74
#                   Head         59         59      0.995          1      0.995      0.954
#                  Mouth          6          6      0.926          1      0.995      0.825
# Speed: 0.2ms preprocess, 2.1ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to C:\Users\jlord\OneDrive\Documents\Programming\FatigueSense\runs\detect\runs\fatigue-v1
# ██████████████████████████████████ 100% | 5.20/5.2 MB [00:10<00:00,  1.98s/MB]:

# %%
import cv2
from ultralytics import YOLO

model = YOLO("./runs/detect/runs/fatigue-v1/weights/best.pt")
cap = cv2.VideoCapture(0)  # 0 = default webcam

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    annotated = results[0].plot()  # draws boxes + labels on frame

    cv2.imshow("FatigueSense - Live Detection", annotated)

    if cv2.waitKey(1) & 0xFF == ord("q"):  # press Q to quit
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Head, 150.2ms
# Speed: 58.8ms preprocess, 150.2ms inference, 21.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 44.2ms
# Speed: 4.2ms preprocess, 44.2ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 39.1ms
# Speed: 2.7ms preprocess, 39.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 35.4ms
# Speed: 2.9ms preprocess, 35.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 54.2ms
# Speed: 3.6ms preprocess, 54.2ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 57.3ms
# Speed: 5.1ms preprocess, 57.3ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 47.1ms
# Speed: 4.1ms preprocess, 47.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 54.1ms
# Speed: 3.1ms preprocess, 54.1ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 47.2ms
# Speed: 4.4ms preprocess, 47.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 34.8ms
# Speed: 3.2ms preprocess, 34.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 38.4ms
# Speed: 3.1ms preprocess, 38.4ms inference, 7.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 35.2ms
# Speed: 2.6ms preprocess, 35.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 35.7ms
# Speed: 3.2ms preprocess, 35.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 36.1ms
# Speed: 2.3ms preprocess, 36.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 40.1ms
# Speed: 3.7ms preprocess, 40.1ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 54.4ms
# Speed: 2.7ms preprocess, 54.4ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 36.5ms
# Speed: 2.7ms preprocess, 36.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 39.8ms
# Speed: 2.8ms preprocess, 39.8ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 36.6ms
# Speed: 2.9ms preprocess, 36.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 39.6ms
# Speed: 3.2ms preprocess, 39.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 
5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.2ms
# Speed: 1.8ms preprocess, 20.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 22.4ms
# Speed: 1.9ms preprocess, 22.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.2ms
# Speed: 1.6ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.2ms
# Speed: 1.6ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.6ms
# Speed: 1.7ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.0ms
# Speed: 2.9ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.5ms
# Speed: 1.4ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.3ms
# Speed: 1.7ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.4ms
# Speed: 1.4ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Eyes, 1 Head, 14.1ms
# Speed: 1.5ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Eyes, 1 Head, 14.3ms
# Speed: 1.4ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.7ms
# Speed: 1.5ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 22.7ms
# Speed: 2.3ms preprocess, 22.7ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 20.6ms
# Speed: 1.8ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 14.9ms
# Speed: 1.6ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 13.7ms
# Speed: 1.7ms preprocess, 13.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.9ms
# Speed: 1.5ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 13.1ms
# Speed: 1.3ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 14.5ms
# Speed: 1.3ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 12.3ms
# Speed: 1.5ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 12.4ms
# Speed: 1.4ms preprocess, 12.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 11.7ms
# Speed: 1.2ms preprocess, 11.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 14.0ms
# Speed: 1.5ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 14.5ms
# Speed: 1.3ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 15.5ms
# Speed: 1.8ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 14.3ms
# Speed: 1.4ms preprocess, 14.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 14.3ms
# Speed: 1.3ms preprocess, 14.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.9ms
# Speed: 1.9ms preprocess, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.3ms
# Speed: 1.3ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.6ms
# Speed: 1.4ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.4ms
# Speed: 1.8ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.8ms
# Speed: 1.2ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.3ms
# Speed: 1.2ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.8ms
# Speed: 1.5ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.5ms
# Speed: 1.4ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.9ms
# Speed: 1.2ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.2ms
# Speed: 1.3ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.1ms
# Speed: 1.4ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.3ms
# Speed: 1.3ms preprocess, 13.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.2ms
# Speed: 1.3ms preprocess, 17.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.4ms
# Speed: 1.3ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.8ms
# Speed: 1.3ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.8ms
# Speed: 1.3ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 16.7ms
# Speed: 1.7ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.5ms
# Speed: 1.7ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.5ms
# Speed: 1.2ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.5ms
# Speed: 1.8ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 11.7ms
# Speed: 1.3ms preprocess, 11.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.4ms
# Speed: 1.3ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.5ms
# Speed: 1.3ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.7ms
# Speed: 1.3ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.9ms
# Speed: 1.2ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.1ms
# Speed: 1.3ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.9ms
# Speed: 1.2ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.7ms
# Speed: 1.4ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.7ms
# Speed: 1.5ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.0ms
# Speed: 1.2ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 10.5ms
# Speed: 1.2ms preprocess, 10.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.3ms
# Speed: 1.3ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.8ms
# Speed: 1.2ms preprocess, 14.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.3ms
# Speed: 1.2ms preprocess, 12.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.4ms
# Speed: 1.6ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 21.4ms
# Speed: 3.0ms preprocess, 21.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.2ms
# Speed: 2.6ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.3ms
# Speed: 1.4ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.8ms
# Speed: 1.4ms preprocess, 15.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.5ms
# Speed: 1.8ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.4ms
# Speed: 1.8ms preprocess, 14.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.4ms
# Speed: 1.6ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 19.2ms
# Speed: 1.9ms preprocess, 19.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 19.9ms
# Speed: 1.8ms preprocess, 19.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.3ms
# Speed: 2.5ms preprocess, 20.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.4ms
# Speed: 1.8ms preprocess, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 19.7ms
# Speed: 2.3ms preprocess, 19.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.9ms
# Speed: 2.8ms preprocess, 15.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.1ms
# Speed: 2.9ms preprocess, 18.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 19.9ms
# Speed: 1.7ms preprocess, 19.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.7ms
# Speed: 2.8ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.2ms
# Speed: 1.4ms preprocess, 13.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.9ms
# Speed: 2.8ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.8ms
# Speed: 1.5ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.8ms
# Speed: 1.4ms preprocess, 14.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.7ms
# Speed: 1.6ms preprocess, 17.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 19.2ms
# Speed: 1.6ms preprocess, 19.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.3ms
# Speed: 1.5ms preprocess, 18.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.0ms
# Speed: 1.7ms preprocess, 18.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 23.5ms
# Speed: 2.8ms preprocess, 23.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 25.5ms
# Speed: 1.7ms preprocess, 25.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.5ms
# Speed: 2.6ms preprocess, 18.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.7ms
# Speed: 1.5ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 23.0ms
# Speed: 1.6ms preprocess, 23.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.9ms
# Speed: 2.4ms preprocess, 18.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.4ms
# Speed: 1.9ms preprocess, 22.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.0ms
# Speed: 1.9ms preprocess, 25.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.7ms
# Speed: 2.2ms preprocess, 18.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.3ms
# Speed: 2.3ms preprocess, 20.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.5ms
# Speed: 2.3ms preprocess, 25.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.2ms
# Speed: 2.7ms preprocess, 16.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 24.8ms
# Speed: 2.1ms preprocess, 24.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.0ms
# Speed: 2.1ms preprocess, 22.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.7ms
# Speed: 2.3ms preprocess, 20.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 21.6ms
# Speed: 1.9ms preprocess, 21.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 22.2ms
# Speed: 3.1ms preprocess, 22.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 24.3ms
# Speed: 2.6ms preprocess, 24.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 23.0ms
# Speed: 2.2ms preprocess, 23.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 21.5ms
# Speed: 2.6ms preprocess, 21.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.4ms
# Speed: 2.5ms preprocess, 20.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.3ms
# Speed: 2.2ms preprocess, 19.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.6ms
# Speed: 2.6ms preprocess, 19.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.2ms
# Speed: 1.6ms preprocess, 18.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.6ms
# Speed: 1.7ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 19.6ms
# Speed: 2.3ms preprocess, 19.6ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.4ms
# Speed: 1.7ms preprocess, 16.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.7ms
# Speed: 1.8ms preprocess, 15.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 34.2ms
# Speed: 2.7ms preprocess, 34.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 35.2ms
# Speed: 3.5ms preprocess, 35.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 28.8ms
# Speed: 2.0ms preprocess, 28.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 23.4ms
# Speed: 1.9ms preprocess, 23.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.3ms
# Speed: 3.1ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.8ms
# Speed: 1.7ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 27.7ms
# Speed: 2.3ms preprocess, 27.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.8ms
# Speed: 2.4ms preprocess, 16.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.4ms
# Speed: 1.7ms preprocess, 17.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.8ms
# Speed: 2.4ms preprocess, 17.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.9ms
# Speed: 1.6ms preprocess, 16.9ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 19.2ms
# Speed: 2.8ms preprocess, 19.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.8ms
# Speed: 1.6ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.5ms
# Speed: 1.8ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.7ms
# Speed: 1.6ms preprocess, 13.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.7ms
# Speed: 1.9ms preprocess, 17.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.9ms
# Speed: 1.4ms preprocess, 16.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.9ms
# Speed: 1.4ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.4ms
# Speed: 1.7ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.8ms
# Speed: 2.4ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.9ms
# Speed: 1.3ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.6ms
# Speed: 1.3ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.1ms
# Speed: 2.6ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.3ms
# Speed: 1.3ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.7ms
# Speed: 2.6ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.9ms
# Speed: 1.4ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.6ms
# Speed: 1.3ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.7ms
# Speed: 1.4ms preprocess, 13.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 27.2ms
# Speed: 1.3ms preprocess, 27.2ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 23.6ms
# Speed: 2.7ms preprocess, 23.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 17.8ms
# Speed: 2.0ms preprocess, 17.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 17.2ms
# Speed: 1.4ms preprocess, 17.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.8ms
# Speed: 1.4ms preprocess, 14.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.1ms
# Speed: 1.7ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.5ms
# Speed: 1.5ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 16.4ms
# Speed: 1.6ms preprocess, 16.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 15.6ms
# Speed: 1.3ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.4ms
# Speed: 1.7ms preprocess, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.3ms
# Speed: 1.4ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 13.7ms
# Speed: 1.4ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.8ms
# Speed: 1.2ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.7ms
# Speed: 1.3ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.6ms
# Speed: 1.7ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 13.9ms
# Speed: 1.2ms preprocess, 13.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.4ms
# Speed: 1.3ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 12.9ms
# Speed: 1.5ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 12.0ms
# Speed: 1.3ms preprocess, 12.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Torso, 1 Head, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Torsos, 1 Head, 12.9ms
# ...
#
# 0: 480x640 1 Head, 22.7ms
# Speed: 2.1ms preprocess, 22.7ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 25.9ms
# Speed: 2.1ms preprocess, 25.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.6ms
# Speed: 3.6ms preprocess, 40.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.3ms
# Speed: 1.9ms preprocess, 21.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 30.1ms
# Speed: 1.9ms preprocess, 30.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.7ms
# Speed: 2.2ms preprocess, 24.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 24.2ms
# Speed: 2.4ms preprocess, 24.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 22.9ms
# Speed: 2.4ms preprocess, 22.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 29.8ms
# Speed: 2.3ms preprocess, 29.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 31.8ms
# Speed: 1.9ms preprocess, 31.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 20.1ms
# Speed: 2.8ms preprocess, 20.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 31.9ms
# Speed: 2.7ms preprocess, 31.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 26.4ms
# Speed: 2.4ms preprocess, 26.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 33.3ms
# Speed: 2.5ms preprocess, 33.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 30.5ms
# Speed: 2.7ms preprocess, 30.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 32.6ms
# Speed: 3.9ms preprocess, 32.6ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 29.8ms
# Speed: 2.8ms preprocess, 29.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 34.7ms
# Speed: 2.7ms preprocess, 34.7ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 33.1ms
# Speed: 2.9ms preprocess, 33.1ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 26.3ms
# Speed: 4.5ms preprocess, 26.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 30.1ms
# Speed: 2.5ms preprocess, 30.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 33.6ms
# Speed: 2.1ms preprocess, 33.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 24.7ms
# Speed: 2.8ms preprocess, 24.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 28.6ms
# Speed: 2.3ms preprocess, 28.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 25.3ms
# Speed: 2.7ms preprocess, 25.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Head, 62.2ms
# Speed: 4.0ms preprocess, 62.2ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#       9 if not ret:
#      10     break
# ---> 12 results = model(frame)
#      13 annotated = results[0].plot()  # draws boxes + labels on frame
#      15 cv2.imshow("FatigueSense - Live Detection", annotated)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
#     534 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535     self.predictor.set_prompts(prompts)
# --> 536 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:334, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     332 # Inference
#     333 with profilers[1]:
# --> 334     preds = self.inference(im, *args, **kwargs)
#     335     if self.args.embed:
#     336         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#     176 """Run inference on a given image using the specified model and arguments."""
#     177 visualize = (
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     179     if self.args.visualize and (not self.source_type.tensor)
#     180     else False
#     181 )
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\autobackend.py:273, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     270 if self.format == "pt":
#     271     forward_kwargs = {"augment": augment, "visualize": visualize, "embed": embed, **kwargs}
# --> 273 y = self.backend.forward(im, **forward_kwargs)
#     275 if isinstance(y, (list, tuple)):
#     276     if len(self.names) == 999 and (self.task == "segment" or len(y) == 2):  # segments and names not defined
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\backends\pytorch.py:90, in PyTorchBackend.forward(self, im, augment, visualize, embed, **kwargs)
#      75 def forward(
#      76     self, im: torch.Tensor, augment: bool = False, visualize: bool = False, embed: list | None = None, **kwargs: Any
#      77 ) -> torch.Tensor | list[torch.Tensor]:
#      78     """Run native PyTorch inference with support for augmentation, visualization, and embeddings.
#      79
#      80     Args:
#    (...)     88         (torch.Tensor | list[torch.Tensor]): Model predictions as tensor(s).
#      89     """
# ---> 90     return self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#     141     return self.loss(x, *args, **kwargs)
# --> 142 return self.predict(x, *args, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     157 if augment:
#     158     return self._predict_augment(x)
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     179 if profile:
#     180     self._profile_one_layer(m, x, dt)
# --> 181 x = m(x)  # run
#     182 y.append(x if m.i in self.save else None)  # save output
#     183 if visualize:
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\modules\block.py:310, in C2f.forward(self, x)
#     308 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     309     """Forward pass through C2f layer."""
# --> 310     y = list(self.cv1(x).chunk(2, 1))
#     311     y.extend(m(y[-1]) for m in self.m)
#     312     return self.cv2(torch.cat(y, 1))
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\modules\conv.py:89, in Conv.forward_fuse(self, x)
#      80 def forward_fuse(self, x):
#      81     """Apply convolution and activation without batch normalization.
#      82
#      83     Args:
#    (...)     87         (torch.Tensor): Output tensor.
#      88     """
# ---> 89     return self.act(self.conv(x))
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\jlord\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
